# %% [markdown]
# # Welcome to Livebook
#
# This is an iPython notebook that runs in your browser. Try out some live coding by editing the cell below.

# %%
"live coding is fun! " * 2
# Out:
# live coding is fun! live coding is fun!

# %% [markdown]
# Load data from the embedded CSV:

# %%
import pandas as pd
data = pd.read_csv('starter.csv')
data
# Out:
# <table><thead><tr><th>&nbsp;</th><th>x</th><th>y</th></tr></thead><tbody><tr><th>0</th><td>1.000000</td><td>1.000000</td></tr><tr><th>1</th><td>2.000000</td><td>3.000000</td></tr><tr><th>2</th><td>5.000000</td><td>2.000000</td></tr><tr><th>3</th><td>6.000000</td><td>5.000000</td></tr></tbody></table>

# %% [markdown]
# The CSV is embedded in the document, so you can use any filename to load it.
#
# Now plot:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 7))
plt.plot(data.x, data.y, '#FF8621')

# %% [markdown]
# Keyboard commands:
#
# * Move cursor up and down with **j** and **k**
# * Edit a cell with **e** and exit edit mode by pressing **esc**
# * Add a new code (Python) cell with **c**
# * Add a new prose (Markdown) cell with **m**
# * Delete a cell with **x**

# %% [markdown]
# Have fun,
#
# — The Livebook team
