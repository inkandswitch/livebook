# %% [markdown]
# # Syntax errors
#
# This cell should run:

# %%
1+1

# %% [markdown]
# This cell should not and thus should be indicated (red highlight) on pageload:

# %%
bad_func()

# %% [markdown]
# This cell should work even though the above one didn't run:

# %%
2+2
# Out:
# (waiting)

# %% [markdown]
# The last one doesn't run and should also be red:

# %%
x = 1
z = x + y
# Out:
# (waiting)
