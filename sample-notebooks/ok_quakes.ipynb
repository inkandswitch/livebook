# %% [markdown]
# # Oklahoma earthquakes over the last 30 years

# %% [markdown]
# Dataset of earthquakes in Oklahoma:

# %%
import pandas as pd
data = pd.read_csv('ok_quakes.csv')
data
# Out:
# <table><thead><tr><th>&nbsp;</th><th>year</th><th>count</th></tr></thead><tbody><tr><th>0</th><td>1974.000000</td><td>1.000000</td></tr><tr><th>1</th><td>1975.000000</td><td>3.000000</td></tr><tr><th>2</th><td>1976.000000</td><td>2.000000</td></tr><tr><th>3</th><td>1977.000000</td><td>0</td></tr><tr><th>4</th><td>1978.000000</td><td>0</td></tr><tr><th>5</th><td>1979.000000</td><td>2.000000</td></tr><tr><th>6</th><td>1980.000000</td><td>1.000000</td></tr><tr><th>7</th><td>1981.000000</td><td>1.000000</td></tr><tr><th>8</th><td>1982.000000</td><td>1.000000</td></tr><tr><th>9</th><td>1983.000000</td><td>0</td></tr><tr><th>10</th><td>1984.000000</td><td>1.000000</td></tr><tr><th>11</th><td>1985.000000</td><td>0</td></tr><tr><th>12</th><td>1986.000000</td><td>0</td></tr><tr><th>13</th><td>1987.000000</td><td>2.000000</td></tr><tr><th>14</th><td>1988.000000</td><td>0</td></tr><tr><th>15</th><td>1989.000000</td><td>1.000000</td></tr><tr><th>16</th><td>1990.000000</td><td>2.000000</td></tr><
# ...

# %% [markdown]
# ## Plot over time

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(2000, 600))
plt.plot(data.year, data.count, '#0a7')

# %% [markdown]
# They are going up :)
